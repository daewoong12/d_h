# %%
import matplotlib

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib.font_manager as fm
for i in fm.fontManager.ttflist:
    if i.name.find('Gulim')!= -1: # Gothic, NanumGothic
        print(i.name)
# Out:
# Gulim
# New Gulim

# %%
from matplotlib import rcParams
rcParams['font.family'] = 'Gulim' # 사용할 폰트 지정
rcParams['axes.unicode_minus'] = False

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x,y)
plt.title('사인 곡선')
plt.xlabel('시간')
plt.ylabel('진폭')
plt.show()

# %% [markdown]
# # 1. 데이터 시각화의 중요성

# %%
import seaborn as sns
anscombe = sns.load_dataset('anscombe')
anscombe
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# 37      IV   8.0   8.47
# 38      IV   8.0   7.04
# 39      IV   8.0   5.25
# 40      IV  19.0  12.50
# 41      IV   8.0   5.56
# 42      IV   8.0   7.91
# 43      IV   8.0   6.89

# %%
anscombe['dataset'].unique()
# Out:
# array(['I', 'II', 'III', 'IV'], dtype=object)

# %% [markdown]
# # 2. Matplotlib 라이브러리

# %%
import matplotlib.pyplot as plt
# plt.plot()

# %%
d1 = anscombe[anscombe['dataset'] == 'I']
d2 = anscombe[anscombe['dataset'] == 'II']
d3 = anscombe[anscombe['dataset'] == 'III']
d4 = anscombe[anscombe['dataset'] == 'IV']
d1.shape
# Out:
# (11, 3)

# %% [markdown]
# ![image.png](attachment:20583ed1-8ba3-475e-82e6-d9b16a809415.png)

# %%
# 2개 요소 x, y
plt.plot(d1['x'], d1['y'])

# %%
# 2개 요소 x, y
plt.plot(d2['x'], d2['y'])

# %%
# 차트를 한 영역 안에 비교할 수 있도록 모아놓는 기능
fig = plt.figure()
axes1 = fig.add_subplot(2, 2, 1) # 2row, 2col, position
axes2 = fig.add_subplot(2, 2, 2) # 2row, 2col, position
axes3 = fig.add_subplot(2, 2, 3) # 2row, 2col, position
axes4 = fig.add_subplot(2, 2, 4) # 2row, 2col, position
plt.show()

# %%
fig = plt.figure()
axes1 = fig.add_subplot(2, 2, 1) # 2row, 2col, position
axes2 = fig.add_subplot(2, 2, 2) # 2row, 2col, position
axes3 = fig.add_subplot(2, 2, 3) # 2row, 2col, position
axes4 = fig.add_subplot(2, 2, 4) # 2row, 2col, position

axes1.plot(d1['x'], d1['y'], 'o')
axes2.plot(d2['x'], d2['y'], 'o')
axes3.plot(d3['x'], d3['y'], 'o')
axes4.plot(d4['x'], d4['y'], 'o')

axes1.set_title('dataset I')
axes2.set_title('dataset II')
axes3.set_title('dataset III')
axes4.set_title('dataset IV')

fig.subtitle('Anscombe Dataset으로 보는 데이터 시각화의 의미')
fig.show
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[67], line 17
#      14 axes3.set_title('dataset III')
#      15 axes4.set_title('dataset IV')
# ---> 17 fig.subtitle('Anscombe Dataset으로 보는 데이터 시각화의 의미')
#      18 fig.show
#      19 plt.show()
#
# AttributeError: 'Figure' object has no attribute 'subtitle'

# %% [markdown]
# 데이터를 요약한 통계만으로 판단하는 것은 완전하지 않다.
#
# 시각화를 통해 경향을 파악하는 것이 중요하다.

# %% [markdown]
# ![image.png](attachment:c51539a4-208c-462c-bc7a-aca1b4f8a747.png)

# %% [markdown]
# ![image.png](attachment:8ee94c00-5a78-4420-ba52-2f086e0376f5.png)

# %% [markdown]
# ![image.png](attachment:c793bef2-9d3e-4a7b-9190-b723196fd69e.png)

# %%
# 새로운 데이터셋 로드
# 'tips' 데이터 셋, 팁, 청구서전체금액, 일행수, 요일, 시간, 흡연여부, 성별

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## 1. 일변량 그래프
# - 히스토그램: 구간의 빈도수를 시각화하는 그래프, x의 구간을 나누어 y는 빈도수

# %%
fig = plt.figure()
axes = fig.add_subplot(1, 1, 1)
axes.hist(data=tips, x = 'total_bill', bins = 20) # bin
plt.show()

# %%
fig = plt.figure()
axes = fig.add_subplot(1, 1, 1)
sns.countplot(data=tips, x = 'day') # bin
plt.show()

# %%
fig = plt.figure()
axes = fig.add_subplot(1, 1, 1)
axes.boxplot(data=tips, x = 'total_bill') # bin
plt.show()

# %% [markdown]
# ## 2. 이변량 그래프

# %% [markdown]
# ### 1. 산점도 (scatter plot)

# %%
fig = plt.figure()
axes = fig.add_subplot(1, 1, 1)
axes.scatter(tips['total_bill'], tips['tip']) # 총지불관계 tip의 관계 '상관관계'
plt.show()

# %% [markdown]
# ### 2. 상자 그림

# %%
fig = plt.figure()
axes = fig.add_subplot(1, 1, 1)
axes.boxplot(
    x=[  tips[tips['sex'] == 'Female' ]['tip'],
         tips[tips['sex'] == 'Male'   ]['tip']
      ], 
    labels=['Female','Male']
) 
plt.show()

# %% [markdown]
# ### 3. 다변량 그래프

# %%
#map()함수에 사용
colors = {"Female": "#f1a340", "Male": "#998ec3"} # 성별에 따른 색상을 지정, 여성은 주황색, 남성은 보라색 
#16진수 코드는 https://www.w3schools.com/colors/colors_picker.asp 에서 확인 가능

scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1, 1, 1)

axes1.scatter(data=tips,
              x='total_bill',
              y='tip',
              s=tips['size']**2*10,# size를 제곱하여 점의 크기를 키움, s는 점의 크기를 나타내는 매개변수
              c=tips['sex'].map(colors),# map()은 Series의 각 요소에 대해 특정 함수를 적용할 때 사용, c는 점의 색을 나타내는 매개변수, colors 딕셔너리에 따라 여성은 주황색, 남성은 보라색
              alpha=0.5) # alpha는 점의 투명도를 나타내는 매개변수

axes1.set_title('Colored by Sex and Sized by Size')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')

scatter_plot.suptitle('Total Bill vs Tip')

plt.show()

# %% [markdown]
# # Seaborn 라이브러리

# %% [markdown]
# ## 1. 일변량 그래프

# %%
sns.histplot(data=tips, x='total_bill')
plt.show()

# %%
sns.kdeplot(data=tips, x='total_bill')
plt.show()

# %%
sns.rugplot(data=tips, x='total_bill')
sns.histplot(data=tips, x='total_bill')
plt.show()

# %%
cnt, ax = plt.subplots()
sns.countplot(data=tips, x='day', palette='viridis')
ax.set_title('요일별 건수')
plt.show()

# %% [markdown]
# ## 2. 이변량 그래프

# %%
cnt, ax = plt.subplots()
sns.scatterplot(data=tips, x = 'total_bill', y = 'tip', hue = 'sex', ax = ax, palette='viridis')
ax.set_title('지불금액과 팁의 관계')
plt.show()

# %%
cnt, ax = plt.subplots()
sns.regplot(data=tips, x = 'total_bill', y = 'tip', ax = ax)
ax.set_title('지불금액과 팁의 관계')
plt.show()

# %%
# joint plot
joint = sns.jointplot(data = tips, x = 'total_bill', y='tip')
joint.set_axis_labels(xlabel='TotalBill', ylabel='Tip')
joint.figure.subtitle('TotalBill과 Tips의 JointChart')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[147], line 4
#       2 joint = sns.jointplot(data = tips, x = 'total_bill', y='tip')
#       3 joint.set_axis_labels(xlabel='TotalBill', ylabel='Tip')
# ----> 4 joint.figure.subtitle('TotalBill과 Tips의 JointChart')
#       5 plt.show()
#
# AttributeError: 'Figure' object has no attribute 'subtitle'

# %%
kde, ax = plt.subplots()
sns.kdeplot(data=tips, x = 'total_bill', y = 'tip', fill=True, ax = ax)
ax.set_title('KDE Plot')
plt.show()

# %%
# bar-plots
bar, ax = plt.subplots()
sns.barplot(data=tips, x='time', y = 'total_bill', estimator=np.mean, ax = ax)
ax.set_title('Bar Plot')
plt.show()

# %%
# boxplot(x= time, y=total_bill)
box, ax = plt.subplots()
sns.boxplot(data=tips, x='time', y = 'total_bill', ax = ax)
ax.set_title('Box Plot')
plt.show()

# %%
# violin plot(x= time, y=total_bill)
bar, ax = plt.subplots()
sns.violinplot(data=tips, x='time', y = 'total_bill', ax = ax)
ax.set_title('Violin Plot')
plt.show()

# %% [markdown]
# ## 3. pairplot

# %%
fig = sns.pairplot(data=tips)
fig.figure.suptitle('Tipsㅇ 데이터의 관계분석')
plt.show()
